# %% [markdown]
# <a href="https://colab.research.google.com/github/JingWunHan/115-1/blob/main/411414999_H1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
A=50000*(1+0.015)**5
print(A)
# Out:
# 53864.20019421873
